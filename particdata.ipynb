# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel(r"C:\Users\mahdi\Desktop\Challenge\undergraduate_data.xlsx")

# %%
data.sample(10)
# Out:
#      1. How comfortable are you with your surroundings in school ?  \
# 184                                                  3
# 116                                                  6
# 162                                                  5
# 41                                                   6
# 124                                                  1
# 242                                                  3
# 46                                                   8
# 170                                                  6
# 85                                                   9
# 153                                                  4
#
#      2. How would you rate the quality of your relationships with your classmates?  \
# 184                                                  5
# 116                                                  5
# 162                                                  3
# 41                                                   7
# ...

# %%
selected_columns = [
    "1. How comfortable are you with your surroundings in school ?",
    "2. How would you rate the quality of your relationships with your classmates?",
    "3. Do you have any close friends at school?",
    "6. Do you sometimes feel isolated in your college environment?",
    "7. How often do external problems affect your academics?",
    '6. Do you sometimes feel isolated in your college  environment?',
    "8. Does your personal relationship (Love Life) affect your academic level?",
    "9. Do you feel comfortable seeking help or advice from friends when facing academic challenges?",
    "10. Are you engaged in any external activities (Associations, Clubs, organizations...) outside of academics? [1. Does your academic study affect your mental well-being? 2. If 'YES' rate it:]",
    "7. Is it tough for you to fulfill your ambitions?",
    "6. How often do you engage in activities that help you relax and unwind? [1. Are you engaged in any physical activities? (gym, sport activity ...) 2. If 'NO', tell us why]",
    "3. Do you often have time to have lunch during the break",
    "5. How many hours of sleep do you get on an average night at university?",
    "3. Do you feel motivated to wake up and go to college?",
    "4. How stressful is school for you?",
    "6. Do you experience any sleep disorders during exams and assessment due to the university environment?",
    "4. Have you ever received training or support in developing emotional resilience skills?"
]

# Creating a new DataFrame with the selected columns
dataQ = data[selected_columns]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\mahdi\Desktop\Challenge\particdata.ipynb Cell 4 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/mahdi/Desktop/Challenge/particdata.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> selected_columns = [
#       <a href='vscode-notebook-cell:/c%3A/Users/mahdi/Desktop/Challenge/particdata.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a>     "1. How comfortable are you with your surroundings in school ?",
#       <a href='vscode-notebook-cell:/c%3A/Users/mahdi/Desktop/Challenge/particdata.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a>     "2. How would you rate the quality of your relationships with your classmates?",
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/mahdi/Desktop/Challenge/particdata.ipynb#W3sZmlsZQ%3D%3D?line=17'>18</a>     "4. Have you ever received training or support in developing emotional resilience skills?"
# ...

# %%
data.columns
# Out:
# Index(['1. How comfortable are you with your surroundings in school ?',
#        '2. How would you rate the quality of your relationships with your classmates?',
#        '3. Do you have any close friends at school?',
#        '5. What is the part of your student life that you are unsatisfied with the most?',
#        '6. Do you sometimes feel isolated in your college  environment?',
#        '7. How often do external problems affect your academics ?',
#        '8. Does your personal relationship (Love Life) affect your academic level  ?',
#        '9. Do you feel comfortable seeking help or advice from friends when facing academic challenges?',
#        '10. Are you engaged in any external activities  (Associations, Clubs, organizations...) outside of academics? ',
#        '1. Does your academic study affect your mental well-being?',
#        '2. If 'YES' rate it: ',
#        '3. Do you feel motivated to wake up and go to college?',
# ...

# %%
lista = data.columns

print(lista)
# Out:
# Index(['1. How comfortable are you with your surroundings in school ?',
#        '2. How would you rate the quality of your relationships with your classmates?',
#        '3. Do you have any close friends at school?',
#        '5. What is the part of your student life that you are unsatisfied with the most?',
#        '6. Do you sometimes feel isolated in your college  environment?',
#        '7. How often do external problems affect your academics ?',
#        '8. Does your personal relationship (Love Life) affect your academic level  ?',
#        '9. Do you feel comfortable seeking help or advice from friends when facing academic challenges?',
#        '10. Are you engaged in any external activities  (Associations, Clubs, organizations...) outside of academics? ',
#        '1. Does your academic study affect your mental well-being?',
#        '2. If 'YES' rate it: ',
#        '3. Do you feel motivated to wake up and go to college?',
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\mahdi\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:554, in NDFrame._get_axis_number(cls, axis)
#     553 try:
# --> 554     return cls._AXIS_TO_AXIS_NUMBER[axis]
#     555 except KeyError:
#
# KeyError: 2
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# c:\Users\mahdi\Desktop\Challenge\particdata.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mahdi/Desktop/Challenge/particdata.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> data.iloc(2).value_counts
#
# File c:\Users\mahdi\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py:668, in _LocationIndexer.__call__(self, axis)
#     665 new_self = type(self)(self.name, self.obj)
# ...

# %%
data.iloc[1:, ]
# Out:
#     8. Does your personal relationship (Love Life) affect your academic level  ?
# 1                                             Disagree
# 2                                             Disagree
# 3                                             Disagree
# 4                                                Agree
# 5                                                Agree
# ..                                                 ...
# 254                                           Disagree
# 255                                              Agree
# 256                                           Disagree
# 257                                           Disagree
# 258                                              Agree
#
# [258 rows x 1 columns]

# %%
data.columns
# Out:
# Index(['1. How comfortable are you with your surroundings in school ?',
#        '2. How would you rate the quality of your relationships with your classmates?',
#        '3. Do you have any close friends at school?',
#        '5. What is the part of your student life that you are unsatisfied with the most?',
#        '6. Do you sometimes feel isolated in your college  environment?',
#        '7. How often do external problems affect your academics ?',
#        '8. Does your personal relationship (Love Life) affect your academic level  ?',
#        '9. Do you feel comfortable seeking help or advice from friends when facing academic challenges?',
#        '10. Are you engaged in any external activities  (Associations, Clubs, organizations...) outside of academics? ',
#        '1. Does your academic study affect your mental well-being?',
#        '2. If 'YES' rate it: ',
#        '3. Do you feel motivated to wake up and go to college?',
# ...

# %%
selected_columns = [
    '1. How comfortable are you with your surroundings in school ?',
    '2. How would you rate the quality of your relationships with your classmates?',
    '3. Do you have any close friends at school?',
    '6. Do you sometimes feel isolated in your college  environment?',
    '7. How often do external problems affect your academics ?',
    '8. Does your personal relationship (Love Life) affect your academic level  ?',
    '9. Do you feel comfortable seeking help or advice from friends when facing academic challenges?',
    '1. Does your academic study affect your mental well-being?',
    '2. If \'YES\' rate it: ',
    '7. Is it tough for you to fulfill your ambitions ?',
    '6. How often do you engage in activities that help you relax and unwind?',
    '1. Are you engaged in any physical activities ? (gym, sport activity ...)',
    '2. If "NO", tell us why ',
    '3. Do you often have time to have lunch during the break',
    '5. How many hours of sleep do you get on an average night at university ?',
    '3. Do you feel motivated to wake up and go to college?',
    '4. How stresseful  school is for you?',
    '6. Do you experience any sleep disorders during exams and assesment due to the university environment ?',
    '4. Have you ever received training or support in developing emotional resilience skills?'
]

# %%
dataQ = data[selected_columns]

# %%
dataQ.sample(10)
# Out:
#      1. How comfortable are you with your surroundings in school ?  \
# 233                                                  7
# 89                                                   6
# 124                                                  1
# 190                                                  7
# 31                                                   6
# 54                                                   7
# 237                                                  4
# 163                                                  5
# 150                                                  4
# 75                                                   3
#
#      2. How would you rate the quality of your relationships with your classmates?  \
# 233                                                  5
# 89                                                   7
# 124                                                  2
# 190                                                  8
# ...

# %%
selected_columns
# Out:
# ['1. How comfortable are you with your surroundings in school ?',
#  '2. How would you rate the quality of your relationships with your classmates?',
#  '3. Do you have any close friends at school?',
#  '6. Do you sometimes feel isolated in your college  environment?',
#  '7. How often do external problems affect your academics ?',
#  '8. Does your personal relationship (Love Life) affect your academic level  ?',
#  '9. Do you feel comfortable seeking help or advice from friends when facing academic challenges?',
#  "1. Does your academic study affect your mental well-being?2. If 'YES' rate it:",
#  '7. Is it tough for you to fulfill your ambitions?',
#  "6. How often do you engage in activities that help you relax and unwind? [1. Are you engaged in any physical activities? (gym, sport activity ...) 2. If 'NO', tell us why]",
#  '3. Do you often have time to have lunch during the break',
#  '5. How many hours of sleep do you get on an average night at university?',
# ...

# %%
# Get the column names from the original DataFrame
column_names = data.columns.tolist()

# Create a mapping of column names to numbers
column_mapping = {name: f'Column_{i+1}' for i, name in enumerate(column_names)}

# Print the column mapping (optional)
print(column_mapping)

# Create a new DataFrame with numbered columns
numbered_data = data.rename(columns=column_mapping)

# Display the new DataFrame
print(numbered_data.head())
# Out:
# {'1. How comfortable are you with your surroundings in school ?': 'Column_1', '2. How would you rate the quality of your relationships with your classmates?': 'Column_2', '3. Do you have any close friends at school?': 'Column_3', '5. What is the part of your student life that you are unsatisfied with the most?': 'Column_4', '6. Do you sometimes feel isolated in your college  environment?': 'Column_5', '7. How often do external problems affect your academics ?': 'Column_6', '8. Does your personal relationship (Love Life) affect your academic level  ?': 'Column_7', '9. Do you feel comfortable seeking help or advice from friends when facing academic challenges?': 'Column_8', '10. Are you engaged in any external activities  (Associations, Clubs, organizations...) outside of academics? ': 'Column_9', '1. Does your academic study affect your mental well-being?': 'Column_10', "2. If 'YES' rate it: ": 'Column_11', '3. Do you feel motivated to wake up and go to college?': 'Column_12', '4. How
# ...

# %%
numbered_data.sample(10)
# Out:
#      Column_1  Column_2 Column_3                           Column_4  \
# 225         9         8      Yes  Teacher, Schedule, Administration
# 244         7         5       No                    Subjects, Exams
# 48          7         7      Yes                        Social life
# 174         8         8      Yes  Teacher, Schedule, Administration
# 16          5         5       No       Social life, Subjects, Exams
# 254         1         1      Yes                        Social life
# 14          8         6      Yes                            Teacher
# 78          2         1       No    Social life, Subjects, Schedule
# 123         6         7       No       Social life, Schedule, Exams
# 189         7         6      Yes          Subjects, Schedule, Exams
#
#       Column_5   Column_6  Column_7       Column_8           Column_9  \
# 225     Rarely     Rarely  Disagree        Neutral      Yes, Too Much
# 244      Never      Never  Disagree        Neutral                 No
# ...

# %%
selected_column_numbers = [0, 1, 2, 5, 6, 5, 7, 8, 9]

# Selecting columns by number
selected_columns_by_number = data.iloc[:, selected_column_numbers]

# Display the selected columns
print(selected_columns_by_number.head())
# Out:
#    1. How comfortable are you with your surroundings in school ?  \
# 0                                                  8
# 1                                                  5
# 2                                                  5
# 3                                                  1
# 4                                                  9
#
#    2. How would you rate the quality of your relationships with your classmates?  \
# 0                                                  8
# 1                                                  7
# 2                                                  5
# 3                                                  3
# 4                                                  9
#
#   3. Do you have any close friends at school?  \
# 0                                         Yes
# 1                                          No
# 2                                         Yes
# 3                                         Yes
# ...

# %%
dataQ = selected_columns_by_number

# %%
data.columns
# Out:
# Index(['1. How comfortable are you with your surroundings in school ?',
#        '2. How would you rate the quality of your relationships with your classmates?',
#        '3. Do you have any close friends at school?',
#        '5. What is the part of your student life that you are unsatisfied with the most?',
#        '6. Do you sometimes feel isolated in your college  environment?',
#        '7. How often do external problems affect your academics ?',
#        '8. Does your personal relationship (Love Life) affect your academic level  ?',
#        '9. Do you feel comfortable seeking help or advice from friends when facing academic challenges?',
#        '10. Are you engaged in any external activities  (Associations, Clubs, organizations...) outside of academics? ',
#        '1. Does your academic study affect your mental well-being?',
#        '2. If 'YES' rate it: ',
#        '3. Do you feel motivated to wake up and go to college?',
# ...

# %%
selected_columns_by_number.columns
# Out:
# Index(['1. How comfortable are you with your surroundings in school ?',
#        '2. How would you rate the quality of your relationships with your classmates?',
#        '3. Do you have any close friends at school?',
#        '7. How often do external problems affect your academics ?',
#        '8. Does your personal relationship (Love Life) affect your academic level  ?',
#        '7. How often do external problems affect your academics ?',
#        '9. Do you feel comfortable seeking help or advice from friends when facing academic challenges?',
#        '10. Are you engaged in any external activities  (Associations, Clubs, organizations...) outside of academics? ',
#        '1. Does your academic study affect your mental well-being?'],
#       dtype='object')

# %%
dataQ = selected_column_by_numbers
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\mahdi\Desktop\Challenge\particdata.ipynb Cell 20 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mahdi/Desktop/Challenge/particdata.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> dataQ = selected_column_by_numbers
#
# NameError: name 'selected_column_by_numbers' is not defined

# %%
dataR

# %%
selected_column_numbers = [4, 15, 28]

# Selecting columns by number
dataR = data.iloc[:, selected_column_numbers]

# Display the selected columns
print(selected_columns_by_number.head())
# Out:
#    1. How comfortable are you with your surroundings in school ?  \
# 0                                                  8
# 1                                                  5
# 2                                                  5
# 3                                                  1
# 4                                                  9
#
#    2. How would you rate the quality of your relationships with your classmates?  \
# 0                                                  8
# 1                                                  7
# 2                                                  5
# 3                                                  3
# 4                                                  9
#
#   3. Do you have any close friends at school?  \
# 0                                         Yes
# 1                                          No
# 2                                         Yes
# 3                                         Yes
# ...

# %%
data.sample(10)
# Out:
#      1. How comfortable are you with your surroundings in school ?  \
# 157                                                  5
# 241                                                  7
# 165                                                  6
# 29                                                   6
# 7                                                    3
# 64                                                   8
# 53                                                   8
# 180                                                  1
# 148                                                  9
# 79                                                   8
#
#      2. How would you rate the quality of your relationships with your classmates?  \
# 157                                                  5
# 241                                                  7
# 165                                                  8
# 29                                                   8
# ...

# %%
dataR.sample(10)
# Out:
#     6. Do you sometimes feel isolated in your college  environment?  \
# 257                                             Always
# 233                                          Sometimes
# 41                                           Sometimes
# 228                                             Rarely
# 62                                           Sometimes
# 119                                          Sometimes
# 227                                              Often
# 209                                          Sometimes
# 125                                             Always
# 76                                              Rarely
#
#     7. Is it tough for you to fulfill your ambitions ?  \
# 257                                                 No
# 233                                                Yes
# 41                                                 Yes
# 228                                                Yes
# 62                                                 Yes
# ...

# %%
dataQ.sample(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\mahdi\Desktop\Challenge\particdata.ipynb Cell 25 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/mahdi/Desktop/Challenge/particdata.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> dataQ.sample(10)
#
# AttributeError: 'list' object has no attribute 'sample'

# %%
dataQ.sample(10)
# Out:
#      1. How comfortable are you with your surroundings in school ?  \
# 170                                                  6
# 231                                                  7
# 182                                                  4
# 129                                                  7
# 122                                                  6
# 102                                                  4
# 84                                                   7
# 47                                                   1
# 62                                                   7
# 195                                                  4
#
#      2. How would you rate the quality of your relationships with your classmates?  \
# 170                                                  5
# 231                                                  6
# 182                                                  4
# 129                                                  7
# ...

# %%
dataR.sample(10)
# Out:
#     6. Do you sometimes feel isolated in your college  environment?  \
# 6                                               Rarely
# 0                                            Sometimes
# 87                                           Sometimes
# 158                                             Rarely
# 218                                             Rarely
# 179                                          Sometimes
# 12                                               Never
# 217                                             Rarely
# 204                                             Rarely
# 45                                           Sometimes
#
#     7. Is it tough for you to fulfill your ambitions ?  \
# 6                                                  Yes
# 0                                                   No
# 87                                                 Yes
# 158                                                 No
# 218                                                Yes
# ...

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
dataQ
# Out:
#      1. How comfortable are you with your surroundings in school ?  \
# 0                                                    8
# 1                                                    5
# 2                                                    5
# 3                                                    1
# 4                                                    9
# 5                                                    6
# 6                                                    5
# 7                                                    3
# 8                                                    7
# 9                                                    1
# 10                                                   5
# 11                                                   9
# 12                                                  10
# 13                                                   8
# 14                                                   8
# 15                                                   7
# ...

# %%
# Out:
#      1. How comfortable are you with your surroundings in school ?  \
# 0                                                    8
# 1                                                    5
# 2                                                    5
# 3                                                    1
# 4                                                    9
# 5                                                    6
# 6                                                    5
# 7                                                    3
# 8                                                    7
# 9                                                    1
# 10                                                   5
# 11                                                   9
# 12                                                  10
# 13                                                   8
# 14                                                   8
# 15                                                   7
# ...

# %%
dataQ
# Out:
#      1. How comfortable are you with your surroundings in school ?  \
# 0                                                    8
# 1                                                    5
# 2                                                    5
# 3                                                    1
# 4                                                    9
# 5                                                    6
# 6                                                    5
# 7                                                    3
# 8                                                    7
# 9                                                    1
# 10                                                   5
# 11                                                   9
# 12                                                  10
# 13                                                   8
# 14                                                   8
# 15                                                   7
# ...

# %%
dataR
# Out:
#     6. Do you sometimes feel isolated in your college  environment?  \
# 0                                            Sometimes
# 1                                            Sometimes
# 2                                            Sometimes
# 3                                            Sometimes
# 4                                            Sometimes
# 5                                               Rarely
# 6                                               Rarely
# 7                                            Sometimes
# 8                                               Rarely
# 9                                                Often
# 10                                              Rarely
# 11                                           Sometimes
# 12                                               Never
# 13                                              Rarely
# 14                                              Rarely
# 15                                              Always
# ...

# %%
dataQ.columns
# Out:
# Index(['1. How comfortable are you with your surroundings in school ?',
#        '2. How would you rate the quality of your relationships with your classmates?',
#        '3. Do you have any close friends at school?',
#        '7. How often do external problems affect your academics ?',
#        '8. Does your personal relationship (Love Life) affect your academic level  ?',
#        '7. How often do external problems affect your academics ?',
#        '9. Do you feel comfortable seeking help or advice from friends when facing academic challenges?',
#        '10. Are you engaged in any external activities  (Associations, Clubs, organizations...) outside of academics? ',
#        '1. Does your academic study affect your mental well-being?'],
#       dtype='object')

# %%
dataR.columns
# Out:
# Index(['6. Do you sometimes feel isolated in your college  environment?',
#        '7. Is it tough for you to fulfill your ambitions ?',
#        '4. Have you ever received training or support in developing emotional resilience skills?'],
#       dtype='object')

# %%
dataQ["2. How would you rate the quality of your relationships with your classmates?"].value_counts()
# Out:
# 5     41
# 7     40
# 8     39
# 6     32
# 4     27
# 3     22
# 9     18
# 2     15
# 1     13
# 10    12
# Name: 2. How would you rate the quality of your relationships with your classmates?, dtype: int64

# %%
dataQ["3. Do you have any close friends at school?"].value_counts()
# Out:
# Yes    185
# No      74
# Name: 3. Do you have any close friends at school?, dtype: int64

# %%
dataQ["3. Do you have any close friends at school?"].value_counts()

# %%
dataQ["7. How often do external problems affect your academics ?"].value_counts
# Out:
# <bound method DataFrame.value_counts of     7. How often do external problems affect your academics ?  \
# 0                                               Rarely
# 1                                               Rarely
# 2                                               Rarely
# 3                                                Often
# 4                                               Always
# 5                                                Often
# 6                                            Sometimes
# 7                                            Sometimes
# 8                                            Sometimes
# 9                                               Rarely
# 10                                           Sometimes
# 11                                              Rarely
# 12                                              Rarely
# 13                                              Rarely
# 14                                           Sometimes
# ...

# %%
dataQ.columns
# Out:
# Index(['1. How comfortable are you with your surroundings in school ?',
#        '2. How would you rate the quality of your relationships with your classmates?',
#        '3. Do you have any close friends at school?',
#        '7. How often do external problems affect your academics ?',
#        '8. Does your personal relationship (Love Life) affect your academic level  ?',
#        '7. How often do external problems affect your academics ?',
#        '9. Do you feel comfortable seeking help or advice from friends when facing academic challenges?',
#        '10. Are you engaged in any external activities  (Associations, Clubs, organizations...) outside of academics? ',
#        '1. Does your academic study affect your mental well-being?'],
#       dtype='object')

# %%
dataR.columns
# Out:
# Index(['6. Do you sometimes feel isolated in your college  environment?',
#        '7. Is it tough for you to fulfill your ambitions ?',
#        '4. Have you ever received training or support in developing emotional resilience skills?'],
#       dtype='object')
